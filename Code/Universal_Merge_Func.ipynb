# %% [markdown]
# # Merging Function for All Datasets

# %%
#!pip install pandas
import pandas as pd

# %%
def read_excel_file(file_name, sheet_name):
    
    #loading excel file 
    xls = pd.ExcelFile(file_name)
    
    df = pd.read_excel(xls, sheet_name) # if contains multiple sheets
    
    return df

# %%
def set_df_col(df):
    
    #replacing header with first row 
    
    df.columns = df.iloc[0] 
    df = df[1:]
    
    return df

# %%
def add_year(df, year, col_num):
    
    year_col = []

    for i in range(0,len(df)):
        year_col.append(year)
        
    df.insert(col_num, "Year", year_col)
    
    return df

# %%
def add_missing_col(df) :
#adding missing columns 
    
    if df['Year'].iloc[0] == '2010' or df['Year'].iloc[0] == '2011' :
        df["% Physically Inactive"] = " "
        
    if df['Year'].iloc[0] == '2011' or df['Year'].iloc[0] == '2012' or df['Year'].iloc[0] == '2013' or df['Year'].iloc[0] == '2014':
        df["Income Ratio"] = " "
        
    return df

# %%
def rename_cols(df): 
    
    df.rename(columns={'Unnamed: 0': "FIPS", 'Unnamed: 1': "State", 'Unnamed: 2': "County"}, inplace=True) #renaming columns  
    
    df.rename(columns = {"% Binge Drinking": "% Excessive Drinking"}, inplace = True)
    
    if df.columns.str.contains("% AFGR").any() :
        df.rename(columns = {"% AFGR": "High School Grad Rate"}, inplace = True)
    elif df.columns.str.contains("AFGR").any() :
        df.rename(columns = {"AFGR": "High School Grad Rate"}, inplace = True)
    elif df.columns.str.contains("Graduation Rate").any() :
        df.rename(columns = {"Graduation Rate": "High School Grad Rate"}, inplace = True)
            
    if df.columns.str.contains("PSED").any() :
        df.rename(columns = {"PSED": "% Some College Education"}, inplace = True)
    elif df.columns.str.contains("% PSED").any() :
        df.rename(columns = {"% PSED": "% Some College Education"}, inplace = True)     
    elif df.columns.str.contains("% College").any() :
        df.rename(columns = {"% College": "% Some College Education"}, inplace = True)
    elif df.columns.str.contains("% Some College").any() :
        df.rename(columns = {"% Some College": "% Some College Education"}, inplace = True)

    if df.columns.str.contains("% unemployed").any() :
        df.rename(columns = {"% unemployed": "% Unemployed"}, inplace = True)
        
    if df.columns.str.contains("GINI").any() :
        df.rename(columns = {"GINI": "Income Ratio"}, inplace = True)
    
    return df

# %%
def extract_clean_df(file_name, sheet_name, replace_header, year, year_col_num, col_list): #col_list = string, replace_header = bool
    
    #create new empty dataframe for return
    clean_df = pd.DataFrame()
    
    #read file
    df = read_excel_file(file_name, sheet_name) # 0: file name, 1: sheet name
    
    #replacing header
    if replace_header == True:
        df = set_df_col(df)
        
    #renaming columns
    df = rename_cols(df)
    
    #insert year
    df = add_year(df, year, year_col_num)  
    
    #insert missing columns
    df = add_missing_col(df)
     
    #extracting columns 
    clean_df = df[col_list].copy()
    
    return clean_df

# %%
def merge_row(merged_df, df) :

    merged_df = merged_df.append(df)
        
    return merged_df

# %%
def del_null_row(df):
    
    #use isnull() pandas function, python None does not work in this case
    
    new_df = df[(df['FIPS'].isnull() == False) & (df['State'].isnull() == False) & (df['County'].isnull() == False)]
    
    return new_df

# %%
def del_nullstate_row(df):
    
    #use isnull() pandas function, python None does not work in this case
    
    new_df = df[(df['FIPS'].isnull() == False) ]
    
    return new_df

# %%
def del_col(df, col_name):
    
    df = df.drop(col_name, axis=1)
    
    return df

# %%
def change_data_type(df, col_list, data_type_list): #first element of col_list correlates to first element of data_type_list
    
    for i in range(0, len(col_list)):
        df[col_list[i]] = df[col_list[i]].astype(data_type_list[i])
        
    return df

# %%
def merge_col(df1, df2, col_list):

    merged_df = pd.DataFrame()
    
    #for i in range(0,len(df_list)-1):
    merged_df = df1.merge(df2, how='outer', on=col_list) #col_list type - string  
        
    return merged_df

# %%
def write_csv_file(df, file_name):
    
    import os as os 
    import os.path
    
    #check if file exists
    if os.path.exists(file_name):
        file = open(file_name, "r")
        file.close()
        #os.remove(file_name) #removing the existing file from the folder 
      
    df.to_csv(file_name) #creating a new csv file
    
    return

# %% [markdown]
# ### Main

# %%
file_sheet_list = [['2010 County Health Rankings Data.xls', 'Ranked Measure Data'],
                   ['2011 County Health Rankings Data.xls', 'Ranked Measure Data'],
                   ['2012 County Health Rankings Data.xls', 'Ranked Measure Data'],
                   ['2013 County Health Rankings Data.xls', 'Ranked Measure Data'],
                   ['2014 County Health Rankings Data.xls', 'Ranked Measure Data'],
                   ['2015 County Health Rankings Data.xls', 'Ranked Measure Data'],
                   ['2016 County Health Rankings Data.xls', 'Ranked Measure Data'],
                   ['2017 County Health Rankings Data.xls', 'Ranked Measure Data'],
                   ['2018 County Health Rankings Data.xls', 'Ranked Measure Data'],
                   ['2019 County Health Rankings Data.xls', 'Ranked Measure Data']]

replace_header = True

#year_list = ['2010', '2011', '2012', '2013']
year_list = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
year_col_num = 3

col_list = ['FIPS', 'State', 'County', 'Year', 'Physically Unhealthy Days','Mentally Unhealthy Days',
                  '% LBW','% Smokers','% Obese','% Physically Inactive','% Excessive Drinking','PCP Rate','High School Grad Rate',
                  '% Some College Education','% Unemployed','% Uninsured','% Children in Poverty','Income Ratio',
                   '% Single-Parent Households'] #string

merged_df = pd.DataFrame()

for i in range(0,len(file_sheet_list)): 
    
    df = extract_clean_df(file_sheet_list[i][0], file_sheet_list[i][1], replace_header, year_list[i], year_col_num, col_list)
    merged_df = merge_row(merged_df, df)

merged_df = del_null_row(merged_df)    

csv_file_name = 'Sociodemo.csv'
write_csv_file(merged_df,csv_file_name)

# %% [markdown]
# ## Merge with Outside Data

# %% [markdown]
# ### Disease & Air Pollution Merge

# %%
#creating new dataframes so they don't duplicate after each run 
sociodem_df = pd.DataFrame()
dis_air_df = pd.DataFrame()

# %%
sociodem_df = pd.read_csv("Sociodemo.csv")
dis_air_df = pd.read_csv("AllData_Andrew.csv")

# %%
col_list_1 = ['FIPS','State','County', 'Year']
data_type_list_1 = [str, str, str, str]
df_list_1 = [dis_air_df, sociodem_df]

df_list_1[0] = change_data_type(df_list_1[0], col_list_1, data_type_list_1)
df_list_1[1] = change_data_type(df_list_1[1], col_list_1, data_type_list_1)

# %%
all_data_df = pd.DataFrame()

# %%
#all_data_df = dis_air_df.merge(sociodem_df, how='outer', on=['FIPS', 'State', 'County', 'Year'])

all_data_df = merge_col(df_list_1[0], df_list_1[1], col_list_1)
all_data_df = del_col(all_data_df, 'Unnamed: 0')
all_data_df = del_col(all_data_df, 'Index')

write_csv_file(all_data_df, 'dis_air_sociodem.csv')

del all_data_df #free memory

# %% [markdown]
# #### Clean Rows

# %%
def del_year_row(df, year_list):
     
    for i in year_list:
        df = df.loc[df['Year']!= i]
    
    return df

# %%
dis_air_sociodem_df = pd.DataFrame()
dis_air_sociodem_df = pd.read_csv('dis_air_sociodem.csv')

# %%
year_list = [1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2020, 2021, 2022]

# %%
dis_air_sociodem_df = del_year_row(dis_air_sociodem_df, year_list)
write_csv_file(dis_air_sociodem_df, 'dis_air_sociodem.csv')

# %%
del dis_air_sociodem_df

# %% [markdown]
# #### Merging Poverty & Demographics Data

# %%
sociodem_df = pd.DataFrame()
sociodem_df = pd.read_csv('Sociodemo.csv')

pov_df = pd.DataFrame()
pov_df = pd.read_csv('poverty_2010-2019.csv')

pov_df['Year'] = pov_df['Year'].astype(str)
pov_df['FIPS'] = pov_df['FIPS'].astype(str)

sociodem_df['FIPS'] = sociodem_df['FIPS'].astype(str)
sociodem_df['Year'] = sociodem_df['Year'].astype(str)

pov_df = pov_df[['FIPS', 'Year', 'Poverty Percent, All Ages']].copy()

# %%
sociodem_pov_df = sociodem_df.merge(pov_df, how='outer', on=['FIPS', 'Year'])
sociodem_pov_df = sociodem_pov_df[sociodem_pov_df['State'].isnull()==False]
sociodem_pov_df
# Out:
#         FIPS    State      County  Year  Physically Unhealthy Days  \
# 0       1001  Alabama     Autauga  2010                   5.480000
# 1       1003  Alabama     Baldwin  2010                   3.570000
# 2       1005  Alabama     Barbour  2010                   6.110000
# 3       1007  Alabama        Bibb  2010                   4.220000
# 4       1009  Alabama      Blount  2010                   5.620000
# ...      ...      ...         ...   ...                        ...
# 31402  56037  Wyoming  Sweetwater  2019                   3.536556
# 31403  56039  Wyoming       Teton  2019                   3.166316
# 31404  56041  Wyoming       Uinta  2019                   3.677538
# 31405  56043  Wyoming    Washakie  2019                   3.601687
# 31406  56045  Wyoming      Weston  2019                   3.448064
#
#        Mentally Unhealthy Days      % LBW  % Smokers  % Obese  \
# 0                     4.140000   8.830000  28.140000     30.0
# 1                     4.060000   8.770000  23.090000     24.5
# 2                     3.840000  11.000000  22.680000     36.4
# 3                     5.310000   9.110000        NaN     31.7
# 4                     4.470000   7.260000  23.420000     31.5
# ...                        ...        ...        ...      ...
# 31402                 3.543546   9.420457  17.566943     30.2
# 31403                 3.072253   7.473928  14.137266     13.6
# 31404                 3.699922   9.647495  18.180586     31.8
# 31405                 3.479694   7.320872  15.607573     29.7
# 31406                 3.418715   6.088561  17.138129     30.9
#
#       % Physically Inactive  % Excessive Drinking    PCP Rate  \
# 0                                       13.590000   52.224775
# 1                                       17.850000   70.741370
# 2                                        9.840000   40.744262
# 3                                        9.540000   42.105263
# 4                                        6.140000   19.987281
# ...                     ...                   ...         ...
# 31402                  25.6             20.325111   33.963550
# 31403                    12             20.451146  120.736490
# 31404                  23.5             16.058559   38.511530
# 31405                    26             16.342995   48.573160
# 31406                  22.5             17.857012   41.459370
#
#        High School Grad Rate  % Some College Education  % Unemployed  \
# 0                  71.518987                 20.643627      4.600000
# 1                  67.043702                 26.321226      4.100000
# 2                  56.342183                 11.186903      7.800000
# 3                  60.383387                 11.000845      5.200000
# 4                  73.013493                 11.618125      4.100000
# ...                      ...                       ...           ...
# 31402              80.067568                 59.295545      4.550299
# 31403              93.464052                 82.004243      2.987005
# 31404              84.687500                 55.891810      4.497702
# 31405              86.290323                 60.132159      4.082625
# 31406              90.123457                 64.788732      3.977725
#
#        % Uninsured  % Children in Poverty Income Ratio  \
# 0        14.000000                   13.8         40.7
# 1        20.900000                   15.3         44.5
# 2        15.100000                   34.1         47.4
# 3        17.700000                   24.2         39.8
# 4        20.800000                   18.5         41.1
# ...            ...                    ...          ...
# 31402    12.750852                   13.4  4.393950545
# 31403    14.979313                    6.9  3.930119004
# 31404    12.568976                   11.8  4.635869103
# 31405    16.708229                   14.0  3.611459192
# 31406    14.352183                   14.0  5.230747057
#
#        % Single-Parent Households Poverty Percent, All Ages
# 0                        8.662107                      11.9
# 1                        8.600628                      13.3
# 2                       14.355162                      25.3
# 3                        5.125778                      20.9
# 4                        7.120596                      16.5
# ...                           ...                       ...
# 31402                   23.461861                       8.3
# 31403                   24.042601                         6
# 31404                   21.645737                       8.5
# 31405                   26.629611                      11.1
# 31406                   28.819213                      10.5
#
# [31407 rows x 20 columns]

# %%
write_csv_file(sociodem_pov_df,'sociodempov.csv')

# %% [markdown]
# #### Merging with Race & Housing

# %%
race_df = pd.DataFrame()
race_df = pd.read_csv('Race_Sociodemo.csv')

race_df['Year'] = race_df['Year'].astype(str)
race_df['FIPS'] = race_df['FIPS'].astype(str)

race_df = race_df.drop(columns=['State','County','Population'])

#race_df.info()
race_df[sociodem_pov_temp_df['FIPS']==10001]
# Out:
# C:\Users\Hannah Chang\AppData\Local\Temp\ipykernel_18096\1287209824.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   race_df[sociodem_pov_temp_df['FIPS']==10001]
#         FIPS  Year  % Age < 18  % Age 65 and over  % African American  \
# 314    10001  2011   25.200000          13.400000           23.300000
# 3455   10001  2012   25.200000          13.400000           23.300000
# 6596   10001  2013   24.474926          13.887305           23.524273
# 9737   10001  2014   24.179423          14.465536           23.614950
# 12878  10001  2015   23.803537          15.068234           23.942839
# 16019  10001  2016   23.558176          15.562223           23.961695
# 19160  12001  2017   18.025957          12.888708           19.948147
# 22297   9015  2018   20.130474          15.680942            1.830591
# 25439   9015  2019   19.807664          16.249710            1.846870
#
#         % Asian  % American Indian/Alaskan Native  \
# 314    2.000000                          0.600000
# 3455   2.000000                          0.600000
# 6596   2.196149                          0.687358
# 9737   2.167930                          0.724660
# 12878  2.214667                          0.723662
# 16019  2.274591                          0.736102
# 19160  6.131618                          0.335431
# 22297  1.452768                          0.665278
# 25439  1.501388                          0.654010
#
#        % Native Hawaiian/Other Pacific Islander  % Hispanic  \
# 314                                    0.100000    4.600000
# 3455                                   0.100000    4.600000
# 6596                                   0.091001    5.993909
# 9737                                   0.088314    6.071897
# 12878                                  0.096803    6.621571
# 16019                                  0.113381    6.887148
# 19160                                  0.075010    9.191657
# 22297                                  0.086925   11.528332
# 25439                                  0.081644   11.684528
#
#        % Non-Hispanic White  % Not Proficient in English   % Female  \
# 314                     NaN                     3.200000  52.100000
# 3455                    NaN                     3.493543  52.100000
# 6596              64.937452                     1.652393  51.821226
# 9737              64.708231                     1.445596  51.844616
# 12878             63.708859                     1.418057  51.805615
# 16019             63.325716                     1.124774  51.772518
# 19160             62.180148                     1.068862  51.628302
# 22297             83.096082                     2.649310  50.435486
# 25439             82.852207                     2.415149  50.311536
#
#          % Rural  Median Household Income  % high housing costs
# 314    35.500000                  55179.0             35.200000
# 3455   35.500000                  51490.0             34.985016
# 6596   26.969380                  51045.0             36.464280
# 9737   26.969380                  51695.0                   NaN
# 12878  26.969380                  53811.0                   NaN
# 16019  26.969380                  54271.0                   NaN
# 19160  21.193437                  47023.0                   NaN
# 22297  49.761036                  60869.0                   NaN
# 25439  49.761036                  62606.0                   NaN

# %%
sociodem_pov_df = sociodem_pov_df.merge(race_df, how='outer', on=['FIPS', 'Year'])
sociodem_pov_df
# Out:
#         FIPS    State      County  Year  Physically Unhealthy Days  \
# 0       1001  Alabama     Autauga  2010                   5.480000
# 1       1003  Alabama     Baldwin  2010                   3.570000
# 2       1005  Alabama     Barbour  2010                   6.110000
# 3       1007  Alabama        Bibb  2010                   4.220000
# 4       1009  Alabama      Blount  2010                   5.620000
# ...      ...      ...         ...   ...                        ...
# 31402  56037  Wyoming  Sweetwater  2019                   3.536556
# 31403  56039  Wyoming       Teton  2019                   3.166316
# 31404  56041  Wyoming       Uinta  2019                   3.677538
# 31405  56043  Wyoming    Washakie  2019                   3.601687
# 31406  56045  Wyoming      Weston  2019                   3.448064
#
#        Mentally Unhealthy Days      % LBW  % Smokers  % Obese  \
# 0                     4.140000   8.830000  28.140000     30.0
# 1                     4.060000   8.770000  23.090000     24.5
# 2                     3.840000  11.000000  22.680000     36.4
# 3                     5.310000   9.110000        NaN     31.7
# 4                     4.470000   7.260000  23.420000     31.5
# ...                        ...        ...        ...      ...
# 31402                 3.543546   9.420457  17.566943     30.2
# 31403                 3.072253   7.473928  14.137266     13.6
# 31404                 3.699922   9.647495  18.180586     31.8
# 31405                 3.479694   7.320872  15.607573     29.7
# 31406                 3.418715   6.088561  17.138129     30.9
#
#       % Physically Inactive  ...   % Asian  % American Indian/Alaskan Native  \
# 0                            ...       NaN                               NaN
# 1                            ...       NaN                               NaN
# 2                            ...       NaN                               NaN
# 3                            ...       NaN                               NaN
# 4                            ...       NaN                               NaN
# ...                     ...  ...       ...                               ...
# 31402                  25.6  ...  0.833831                          1.534433
# 31403                    12  ...  1.229314                          0.906942
# 31404                  23.5  ...  0.492803                          1.395462
# 31405                    26  ...  0.756448                          1.723710
# 31406                  22.5  ...  1.198210                          1.631298
#
#        % Native Hawaiian/Other Pacific Islander  % Hispanic  \
# 0                                           NaN         NaN
# 1                                           NaN         NaN
# 2                                           NaN         NaN
# 3                                           NaN         NaN
# 4                                           NaN         NaN
# ...                                         ...         ...
# 31402                                  0.142417   16.249368
# 31403                                  0.133247   14.983881
# 31404                                  0.175653    9.163211
# 31405                                  0.111607   14.248512
# 31406                                  0.028873    4.186517
#
#        % Non-Hispanic White  % Not Proficient in English   % Female  \
# 0                       NaN                          NaN        NaN
# 1                       NaN                          NaN        NaN
# 2                       NaN                          NaN        NaN
# 3                       NaN                          NaN        NaN
# 4                       NaN                          NaN        NaN
# ...                     ...                          ...        ...
# 31402             79.358662                     1.582845  48.454082
# 31403             81.702128                     4.042033  48.098001
# 31404             87.474994                     0.911363  49.573067
# 31405             82.428075                     0.346198  49.466766
# 31406             90.948463                     0.698262  47.538617
#
#          % Rural  Median Household Income % high housing costs
# 0            NaN                      NaN                  NaN
# 1            NaN                      NaN                  NaN
# 2            NaN                      NaN                  NaN
# 3            NaN                      NaN                  NaN
# 4            NaN                      NaN                  NaN
# ...          ...                      ...                  ...
# 31402  10.916313                  75590.0                  NaN
# 31403  46.430920                  90145.0                  NaN
# 31404  43.095937                  67404.0                  NaN
# 31405  35.954529                  57989.0                  NaN
# 31406  54.536626                  56214.0                  NaN
#
# [31407 rows x 33 columns]

# %%
write_csv_file(sociodem_pov_df, 'sociodempov.csv')

# %% [markdown]
# #### Merging with Temperature

# %%
sociodem_pov_temp_df = pd.DataFrame()
sociodem_pov_temp_df = pd.read_csv('sociodempov.csv')

temp_df = pd.DataFrame()
temp_df = pd.read_csv("seasonal_temp_data_2000-2016.csv")

temp_df['FIPS'] = temp_df['FIPS'].astype(str)
temp_df['Year'] = temp_df['Year'].astype(str)
# Out:
# C:\Users\Hannah Chang\AppData\Local\Temp\ipykernel_18096\3434578485.py:2: DtypeWarning: Columns (10,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   sociodem_pov_temp_df = pd.read_csv('sociodempov.csv')

# %%
sociodem_pov_temp_df = sociodem_pov_df.merge(temp_df, how='outer', on=['FIPS', 'Year'])
sociodem_pov_temp_df = sociodem_pov_temp_df[sociodem_pov_temp_df['State'].isnull() ==False]
sociodem_pov_temp_df = sociodem_pov_temp_df.drop(columns=['State', 'County'])
sociodem_pov_temp_df
# Out:
#         FIPS  Year  Physically Unhealthy Days  Mentally Unhealthy Days  \
# 0       1001  2010                   5.480000                 4.140000
# 1       1003  2010                   3.570000                 4.060000
# 2       1005  2010                   6.110000                 3.840000
# 3       1007  2010                   4.220000                 5.310000
# 4       1009  2010                   5.620000                 4.470000
# ...      ...   ...                        ...                      ...
# 31402  56037  2019                   3.536556                 3.543546
# 31403  56039  2019                   3.166316                 3.072253
# 31404  56041  2019                   3.677538                 3.699922
# 31405  56043  2019                   3.601687                 3.479694
# 31406  56045  2019                   3.448064                 3.418715
#
#            % LBW  % Smokers  % Obese % Physically Inactive  \
# 0       8.830000  28.140000     30.0
# 1       8.770000  23.090000     24.5
# 2      11.000000  22.680000     36.4
# 3       9.110000        NaN     31.7
# 4       7.260000  23.420000     31.5
# ...          ...        ...      ...                   ...
# 31402   9.420457  17.566943     30.2                  25.6
# 31403   7.473928  14.137266     13.6                    12
# 31404   9.647495  18.180586     31.8                  23.5
# 31405   7.320872  15.607573     29.7                    26
# 31406   6.088561  17.138129     30.9                  22.5
#
#        % Excessive Drinking    PCP Rate  ...  % Non-Hispanic White  \
# 0                 13.590000   52.224775  ...                   NaN
# 1                 17.850000   70.741370  ...                   NaN
# 2                  9.840000   40.744262  ...                   NaN
# 3                  9.540000   42.105263  ...                   NaN
# 4                  6.140000   19.987281  ...                   NaN
# ...                     ...         ...  ...                   ...
# 31402             20.325111   33.963550  ...             79.358662
# 31403             20.451146  120.736490  ...             81.702128
# 31404             16.058559   38.511530  ...             87.474994
# 31405             16.342995   48.573160  ...             82.428075
# 31406             17.857012   41.459370  ...             90.948463
#
#        % Not Proficient in English   % Female    % Rural  \
# 0                              NaN        NaN        NaN
# 1                              NaN        NaN        NaN
# 2                              NaN        NaN        NaN
# 3                              NaN        NaN        NaN
# 4                              NaN        NaN        NaN
# ...                            ...        ...        ...
# 31402                     1.582845  48.454082  10.916313
# 31403                     4.042033  48.098001  46.430920
# 31404                     0.911363  49.573067  43.095937
# 31405                     0.346198  49.466766  35.954529
# 31406                     0.698262  47.538617  54.536626
#
#        Median Household Income % high housing costs  summer_tmmx summer_rmax  \
# 0                          NaN                  NaN   307.301620   95.930844
# 1                          NaN                  NaN   306.362271   95.062925
# 2                          NaN                  NaN   307.031201   96.743853
# 3                          NaN                  NaN   307.045058   96.478311
# 4                          NaN                  NaN   306.453123   96.377585
# ...                        ...                  ...          ...         ...
# 31402                  75590.0                  NaN          NaN         NaN
# 31403                  90145.0                  NaN          NaN         NaN
# 31404                  67404.0                  NaN          NaN         NaN
# 31405                  57989.0                  NaN          NaN         NaN
# 31406                  56214.0                  NaN          NaN         NaN
#
#        winter_tmmx  winter_rmax
# 0       284.516593    85.556321
# 1       287.316057    88.375102
# 2       285.548278    86.601035
# 3       283.897197    85.695587
# 4       281.889789    84.789725
# ...            ...          ...
# 31402          NaN          NaN
# 31403          NaN          NaN
# 31404          NaN          NaN
# 31405          NaN          NaN
# 31406          NaN          NaN
#
# [31407 rows x 35 columns]

# %%
sociodem_pov_temp_df[sociodem_pov_temp_df['FIPS']==10001]
# Out:
#         FIPS  Year  Physically Unhealthy Days  Mentally Unhealthy Days  \
# 314    10001  2010                   3.680000                 3.610000
# 3455   10001  2011                   3.700000                 3.600000
# 6596   10001  2012                   3.800000                 3.600000
# 9737   10001  2013                   3.800000                 3.600000
# 12878  10001  2014                   3.700000                 3.500000
# 16019  10001  2015                   3.700000                 3.500000
# 19160  10001  2016                   3.600000                 3.800000
# 22297  10001  2017                   3.475073                 4.035169
# 25439  10001  2018                   3.535874                 3.681000
# 28581  10001  2019                   3.535874                 3.681000
#
#           % LBW  % Smokers  % Obese % Physically Inactive  \
# 314    9.240000  23.920000     31.2
# 3455   9.340000  23.000000     32.4
# 6596   9.200000  22.300000     32.7                  28.2
# 9737   8.800000  21.900000     32.7                  28.2
# 12878  8.600000  21.200000     33.8                  27.6
# 16019  8.528471  21.200000     32.7                  27.4
# 19160  8.476975  18.200000     33.2                  28.1
# 22297  8.451250  19.019157     32.8                  27.8
# 25439  8.882616  18.170641     33.6                  30.3
# 28581  9.030211  18.170641     33.8                  29.5
#
#        % Excessive Drinking   PCP Rate  ...  % Non-Hispanic White  \
# 314               15.130000  50.944213  ...                   NaN
# 3455              16.300000  49.520233  ...                   NaN
# 6596              16.000000  49.520233  ...                   NaN
# 9737              16.400000  51.573930  ...             64.937452
# 12878             16.100000  49.747020  ...             64.708231
# 16019             16.100000  60.849750  ...             63.708859
# 19160             15.300000  60.797090  ...             63.325716
# 22297             15.421028  47.096580  ...             62.845107
# 25439             16.445973  45.524480  ...             62.411412
# 28581             16.445973  44.615530  ...             61.714473
#
#        % Not Proficient in English   % Female   % Rural  \
# 314                            NaN        NaN       NaN
# 3455                      3.200000  52.100000  35.50000
# 6596                      3.493543  52.100000  35.50000
# 9737                      1.652393  51.821226  26.96938
# 12878                     1.445596  51.844616  26.96938
# 16019                     1.418057  51.805615  26.96938
# 19160                     1.124774  51.772518  26.96938
# 22297                     1.219181  51.795912  26.96938
# 25439                     1.151782  51.843823  26.96938
# 28581                     1.268547  51.821585  26.96938
#
#        Median Household Income % high housing costs  summer_tmmx summer_rmax  \
# 314                        NaN                  NaN   303.868674   88.387689
# 3455                   55179.0            35.200000   304.583917   91.653776
# 6596                   51490.0            34.985016   305.124542   89.518368
# 9737                   51045.0            36.464280   303.193939   94.577484
# 12878                  51695.0                  NaN   301.739543   87.214805
# 16019                  53811.0                  NaN   302.029036   93.031164
# 19160                  54271.0                  NaN   303.174632   93.299935
# 22297                  55678.0                  NaN          NaN         NaN
# 25439                  53994.0                  NaN          NaN         NaN
# 28581                  57112.0                  NaN          NaN         NaN
#
#        winter_tmmx  winter_rmax
# 314     278.272359    84.192369
# 3455    278.553625    81.011010
# 6596    283.837644    83.452235
# 9737    282.429366    83.507429
# 12878   279.748024    85.535824
# 16019   278.386625    85.130999
# 19160   283.159273    84.397250
# 22297          NaN          NaN
# 25439          NaN          NaN
# 28581          NaN          NaN
#
# [10 rows x 35 columns]

# %%
write_csv_file(sociodem_pov_temp_df,"sociodempovtemp.csv")

# %% [markdown]
# #### Merging with Disease/Pollution

# %%
dis_air_df = pd.DataFrame()
sociodem_pov_temp_df = pd.DataFrame()

dis_air_df = pd.read_csv("AllData_Andrew.csv")
sociodem_pov_temp_df = pd.read_csv("sociodempovtemp.csv")

dis_air_df = dis_air_df.drop(columns='Index')
# Out:
# C:\Users\Hannah Chang\AppData\Local\Temp\ipykernel_18096\1462951649.py:5: DtypeWarning: Columns (7,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   sociodem_pov_temp_df = pd.read_csv("sociodempovtemp.csv")

# %%
dis_air_df = dis_air_df[(dis_air_df['Year']== 2010) | (dis_air_df['Year']== 2011) |
                        (dis_air_df['Year']== 2012) | (dis_air_df['Year']== 2013) |
                        (dis_air_df['Year']== 2014) | (dis_air_df['Year']== 2015) |
                        (dis_air_df['Year']== 2016) | (dis_air_df['Year']== 2017) |
                        (dis_air_df['Year']== 2018) | (dis_air_df['Year']== 2019)]

# %%
sociodem_pov_temp_df[sociodem_pov_temp_df['FIPS']==10001]
# Out:
#         FIPS  Year  Physically Unhealthy Days  Mentally Unhealthy Days  \
# 314    10001  2010                   3.680000                 3.610000
# 3455   10001  2011                   3.700000                 3.600000
# 6596   10001  2012                   3.800000                 3.600000
# 9737   10001  2013                   3.800000                 3.600000
# 12878  10001  2014                   3.700000                 3.500000
# 16019  10001  2015                   3.700000                 3.500000
# 19160  10001  2016                   3.600000                 3.800000
# 22297  10001  2017                   3.475073                 4.035169
# 25439  10001  2018                   3.535874                 3.681000
# 28581  10001  2019                   3.535874                 3.681000
#
#           % LBW  % Smokers  % Obese % Physically Inactive  \
# 314    9.240000  23.920000     31.2
# 3455   9.340000  23.000000     32.4
# 6596   9.200000  22.300000     32.7                  28.2
# 9737   8.800000  21.900000     32.7                  28.2
# 12878  8.600000  21.200000     33.8                  27.6
# 16019  8.528471  21.200000     32.7                  27.4
# 19160  8.476975  18.200000     33.2                  28.1
# 22297  8.451250  19.019157     32.8                  27.8
# 25439  8.882616  18.170641     33.6                  30.3
# 28581  9.030211  18.170641     33.8                  29.5
#
#        % Excessive Drinking   PCP Rate  ...  % Non-Hispanic White  \
# 314               15.130000  50.944213  ...                   NaN
# 3455              16.300000  49.520233  ...                   NaN
# 6596              16.000000  49.520233  ...                   NaN
# 9737              16.400000  51.573930  ...             64.937452
# 12878             16.100000  49.747020  ...             64.708231
# 16019             16.100000  60.849750  ...             63.708859
# 19160             15.300000  60.797090  ...             63.325716
# 22297             15.421028  47.096580  ...             62.845107
# 25439             16.445973  45.524480  ...             62.411412
# 28581             16.445973  44.615530  ...             61.714473
#
#        % Not Proficient in English   % Female   % Rural  \
# 314                            NaN        NaN       NaN
# 3455                      3.200000  52.100000  35.50000
# 6596                      3.493543  52.100000  35.50000
# 9737                      1.652393  51.821226  26.96938
# 12878                     1.445596  51.844616  26.96938
# 16019                     1.418057  51.805615  26.96938
# 19160                     1.124774  51.772518  26.96938
# 22297                     1.219181  51.795912  26.96938
# 25439                     1.151782  51.843823  26.96938
# 28581                     1.268547  51.821585  26.96938
#
#        Median Household Income % high housing costs  summer_tmmx summer_rmax  \
# 314                        NaN                  NaN   303.868674   88.387689
# 3455                   55179.0            35.200000   304.583917   91.653776
# 6596                   51490.0            34.985016   305.124542   89.518368
# 9737                   51045.0            36.464280   303.193939   94.577484
# 12878                  51695.0                  NaN   301.739543   87.214805
# 16019                  53811.0                  NaN   302.029036   93.031164
# 19160                  54271.0                  NaN   303.174632   93.299935
# 22297                  55678.0                  NaN          NaN         NaN
# 25439                  53994.0                  NaN          NaN         NaN
# 28581                  57112.0                  NaN          NaN         NaN
#
#        winter_tmmx  winter_rmax
# 314     278.272359    84.192369
# 3455    278.553625    81.011010
# 6596    283.837644    83.452235
# 9737    282.429366    83.507429
# 12878   279.748024    85.535824
# 16019   278.386625    85.130999
# 19160   283.159273    84.397250
# 22297          NaN          NaN
# 25439          NaN          NaN
# 28581          NaN          NaN
#
# [10 rows x 35 columns]

# %%
dis_air_df
# Out:
#         FIPS  Year        State   County  Population  Latitude  Longitude  \
# 11     10001  2010     Delaware     Kent    162310.0    39.086   -75.5686
# 12     10001  2011     Delaware     Kent    164834.0    39.086   -75.5686
# 13     10001  2012     Delaware     Kent    167626.0    39.086   -75.5686
# 14     10001  2013     Delaware     Kent    169416.0    39.086   -75.5686
# 15     10001  2014     Delaware     Kent    171987.0    39.086   -75.5686
# ...      ...   ...          ...      ...         ...       ...        ...
# 75400   9015  2015  Connecticut  Windham    116573.0    41.830   -71.9874
# 75401   9015  2016  Connecticut  Windham    116192.0    41.830   -71.9874
# 75402   9015  2017  Connecticut  Windham    116359.0    41.830   -71.9874
# 75403   9015  2018  Connecticut  Windham    117027.0    41.830   -71.9874
# 75404   9015  2019  Connecticut  Windham    116782.0    41.830   -71.9874
#
#        Alzheimers Deaths  Cerebrovascular Disease Deaths  \
# 11                  34.0                            57.0
# 12                  42.0                            51.0
# 13                  40.0                            80.0
# 14                  29.0                            61.0
# 15                  21.0                            76.0
# ...                  ...                             ...
# 75400               37.0                            56.0
# 75401               36.0                            31.0
# 75402               37.0                            41.0
# 75403               26.0                            34.0
# 75404               35.0                            44.0
#
#        Chronic liver disease and cirrhosis Deaths  ...  CO 8-hour 1971  \
# 11                                           20.0  ...             NaN
# 12                                           17.0  ...             NaN
# 13                                            NaN  ...             NaN
# 14                                           11.0  ...             NaN
# 15                                           22.0  ...             NaN
# ...                                           ...  ...             ...
# 75400                                        17.0  ...             NaN
# 75401                                        19.0  ...             NaN
# 75402                                        10.0  ...             NaN
# 75403                                        14.0  ...             NaN
# 75404                                        15.0  ...             NaN
#
#        Lead 3-Month 2009  NO2 1-hour 2010  NO2 Annual 1971  Ozone 8-hour 2015  \
# 11                   NaN              NaN              NaN           0.049462
# 12                   NaN              NaN              NaN           0.046864
# 13                   NaN              NaN              NaN           0.049642
# 14                   NaN              NaN              NaN           0.044270
# 15                   NaN              NaN              NaN           0.043709
# ...                  ...              ...              ...                ...
# 75400                NaN              NaN              NaN           0.043469
# 75401                NaN              NaN              NaN           0.043234
# 75402                NaN              NaN              NaN           0.040923
# 75403                NaN              NaN              NaN           0.041871
# 75404                NaN              NaN              NaN           0.042395
#
#        PM10 24-hour 2006  PM25 24-hour 2012  PM25 Annual 2012  \
# 11                   NaN           9.539514          9.539514
# 12                   NaN           8.820699          8.820699
# 13                   NaN           8.205308          8.205308
# 14                   NaN           8.018102          8.018102
# 15                   NaN           8.246808          8.246808
# ...                  ...                ...               ...
# 75400                NaN                NaN               NaN
# 75401                NaN                NaN               NaN
# 75402                NaN                NaN               NaN
# 75403                NaN                NaN               NaN
# 75404                NaN                NaN               NaN
#
#        SO2 1-hour 2010  SO2 3-hour 1971
# 11                 NaN              NaN
# 12                 NaN              NaN
# 13                 NaN              NaN
# 14                 NaN              NaN
# 15                 NaN              NaN
# ...                ...              ...
# 75400              NaN              NaN
# 75401              NaN              NaN
# 75402              NaN              NaN
# 75403              NaN              NaN
# 75404              NaN              NaN
#
# [31420 rows x 30 columns]

# %%
disair_sociodem_pov_temp_df = dis_air_df.merge(sociodem_pov_temp_df, how='outer', on=['FIPS', 'Year'])
disair_sociodem_pov_temp_df = disair_sociodem_pov_temp_df[disair_sociodem_pov_temp_df['State'].isnull()==False]
disair_sociodem_pov_temp_df['% Age < 18'].head(20)
# Out:
# 0           NaN
# 1     25.200000
# 2     25.200000
# 3     24.474926
# 4     24.179423
# 5     23.803537
# 6     23.558176
# 7     23.253790
# 8     23.039919
# 9     22.967470
# 10          NaN
# 11    23.800000
# 12    23.800000
# 13    22.842182
# 14    22.653806
# 15    22.334650
# 16    22.174725
# 17    21.951977
# 18    21.864963
# 19    21.685516
# Name: % Age < 18, dtype: float64

# %%
write_csv_file(disair_sociodem_pov_temp_df, 'AllData_w_demo.csv')

# %% [markdown]
# ### New Disease Dataset Merge

# %%
demo = pd.DataFrame() 
newdis = pd.DataFrame() 

demo = pd.read_csv('AllData_w_demo.csv')
newdis = pd.read_csv('AllDataNew.csv')
# Out:
# C:\Users\Hannah Chang\AppData\Local\Temp\ipykernel_18096\1866782900.py:4: DtypeWarning: Columns (45) have mixed types. Specify dtype option on import or set low_memory=False.
#   demo = pd.read_csv('AllData_w_demo.csv')

# %%
newdis_df = newdis.drop(newdis.loc[:,'age_pct_0_14':'winter_tmmx'], axis=1)
newdis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69124 entries, 0 to 69123
# Data columns (total 45 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Index                                                                           69124 non-null  object
#  1   FIPS                                                                            69124 non-null  int64
#  2   Year                                                                            69124 non-null  int64
#  3   State                                                                           69124 non-null  object
#  4   County                                                                          69124 non-null  object
#  5   Population                                                                      68996 non-null  float64
#  6   Latitude                                                                        69102 non-null  float64
#  7   Longitude                                                                       69102 non-null  float64
#  8   Acute upper respiratory infections (J00-J06) Deaths                             1 non-null      float64
#  9   All Causes of Death Deaths                                                      68186 non-null  float64
#  10  Alzheimer disease (G30) Deaths                                                  31602 non-null  float64
#  11  Asthma (J45-J46) Deaths                                                         1536 non-null   float64
#  12  Bronchus and lung - In situ neoplasms (D02.2) Deaths                            0 non-null      float64
#  13  Cerebrovascular diseases (I60-I69) Deaths                                       45145 non-null  float64
#  14  Chronic liver disease and cirrhosis (K70,K73-K74) Deaths                        15262 non-null  float64
#  15  Chronic lower respiratory diseases (J40-J47) Deaths                             45882 non-null  float64
#  16  Diabetes mellitus (E10-E14) Deaths                                              30908 non-null  float64
#  17  Diseases of heart (I00-I09,I11,I13,I20-I51) Deaths                              64316 non-null  float64
#  18  Essential hypertension and hypertensive renal disease (I10,I12,I15) Deaths      12274 non-null  float64
#  19  Extremely low birth weight and Other low birth weight (P07.0 and P07.1) Deaths  19 non-null     float64
#  20  Influenza and pneumonia (J09-J18) Deaths                                        25229 non-null  float64
#  21  Ischaemic heart diseases (I20-I25) Deaths                                       60069 non-null  float64
#  22  Malignant neoplasm of bronchus and lung (C34) Deaths                            46921 non-null  float64
#  23  Malignant neoplasms (C00-C97) Deaths                                            63463 non-null  float64
#  24  Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) Deaths    21359 non-null  float64
#  25  Other chronic obstructive pulmonary disease (J44) Deaths                        43287 non-null  float64
#  26  Parkinson disease (G20-G21) Deaths                                              11440 non-null  float64
#  27  Tuberculosis (A16-A19) Deaths                                                   104 non-null    float64
#  28  CO 1-hour 1971                                                                  4555 non-null   float64
#  29  CO 8-hour 1971                                                                  4555 non-null   float64
#  30  Lead 3-Month 2009                                                               991 non-null    float64
#  31  NO2 1-hour 2010                                                                 5525 non-null   float64
#  32  NO2 Annual 1971                                                                 5526 non-null   float64
#  33  Ozone 8-hour 2015                                                               16742 non-null  float64
#  34  PM10 24-hour 2006                                                               9201 non-null   float64
#  35  PM25 24-hour 2012                                                               13592 non-null  float64
#  36  PM25 Annual 2012                                                                13592 non-null  float64
#  37  SO2 1-hour 2010                                                                 7143 non-null   float64
#  38  SO2 3-hour 1971                                                                 7143 non-null   float64
#  39  Lead 3-Month 2009 1 and 2 Indicator                                             991 non-null    float64
#  40  PM25 Annual 2012 1 Indicator                                                    13592 non-null  float64
#  41  PM25 Annual 2012 2 Indicator                                                    13592 non-null  float64
#  42  PM25 24-hour 2012 1 and 2 Indicator                                             13592 non-null  float64
#  43  SO2 1-hour 2010 1 Indicator                                                     7143 non-null   float64
#  44  SO2 3-hour 1971 2 Indicator                                                     7143 non-null   float64
# dtypes: float64(40), int64(2), object(3)
# memory usage: 23.7+ MB

# %%
demo_df = demo.drop(demo.iloc[:,2:30], axis=1)
demo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31420 entries, 0 to 31419
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   FIPS                                      31420 non-null  int64
#  1   Year                                      31420 non-null  int64
#  2   Physically Unhealthy Days                 29836 non-null  float64
#  3   Mentally Unhealthy Days                   29370 non-null  float64
#  4   % LBW                                     29746 non-null  float64
#  5   % Smokers                                 27925 non-null  float64
#  6   % Obese                                   31364 non-null  float64
#  7   % Physically Inactive                     31364 non-null  object
#  8   % Excessive Drinking                      27392 non-null  float64
#  9   PCP Rate                                  30261 non-null  float64
#  10  High School Grad Rate                     28671 non-null  float64
#  11  % Some College Education                  31363 non-null  float64
#  12  % Unemployed                              31354 non-null  float64
#  13  % Uninsured                               31354 non-null  float64
#  14  % Children in Poverty                     31354 non-null  float64
#  15  Income Ratio                              31359 non-null  object
#  16  % Single-Parent Households                31352 non-null  float64
#  17  Poverty Percent, All Ages                 31364 non-null  object
#  18  % Age < 18                                28229 non-null  float64
#  19  % Age 65 and over                         28229 non-null  float64
#  20  % African American                        28229 non-null  float64
#  21  % Asian                                   28229 non-null  float64
#  22  % American Indian/Alaskan Native          28229 non-null  float64
#  23  % Native Hawaiian/Other Pacific Islander  28229 non-null  float64
#  24  % Hispanic                                28229 non-null  float64
#  25  % Non-Hispanic White                      21959 non-null  float64
#  26  % Not Proficient in English               28229 non-null  float64
#  27  % Female                                  28229 non-null  float64
#  28  % Rural                                   28213 non-null  float64
#  29  Median Household Income                   28220 non-null  float64
#  30  % high housing costs                      9405 non-null   float64
#  31  summer_tmmx                               21749 non-null  float64
#  32  summer_rmax                               21749 non-null  float64
#  33  winter_tmmx                               21749 non-null  float64
#  34  winter_rmax                               21749 non-null  float64
# dtypes: float64(30), int64(2), object(3)
# memory usage: 8.4+ MB

# %%
AllData = pd.merge(newdis_df, demo_df, how='outer', on=['FIPS', 'Year'])
AllData = AllData.drop(columns=['Index'])

#AllData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69124 entries, 0 to 69123
# Data columns (total 77 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   FIPS                                                                            69124 non-null  int64
#  1   Year                                                                            69124 non-null  int64
#  2   State                                                                           69124 non-null  object
#  3   County                                                                          69124 non-null  object
#  4   Population                                                                      68996 non-null  float64
#  5   Latitude                                                                        69102 non-null  float64
#  6   Longitude                                                                       69102 non-null  float64
#  7   Acute upper respiratory infections (J00-J06) Deaths                             1 non-null      float64
#  8   All Causes of Death Deaths                                                      68186 non-null  float64
#  9   Alzheimer disease (G30) Deaths                                                  31602 non-null  float64
#  10  Asthma (J45-J46) Deaths                                                         1536 non-null   float64
#  11  Bronchus and lung - In situ neoplasms (D02.2) Deaths                            0 non-null      float64
#  12  Cerebrovascular diseases (I60-I69) Deaths                                       45145 non-null  float64
#  13  Chronic liver disease and cirrhosis (K70,K73-K74) Deaths                        15262 non-null  float64
#  14  Chronic lower respiratory diseases (J40-J47) Deaths                             45882 non-null  float64
#  15  Diabetes mellitus (E10-E14) Deaths                                              30908 non-null  float64
#  16  Diseases of heart (I00-I09,I11,I13,I20-I51) Deaths                              64316 non-null  float64
#  17  Essential hypertension and hypertensive renal disease (I10,I12,I15) Deaths      12274 non-null  float64
#  18  Extremely low birth weight and Other low birth weight (P07.0 and P07.1) Deaths  19 non-null     float64
#  19  Influenza and pneumonia (J09-J18) Deaths                                        25229 non-null  float64
#  20  Ischaemic heart diseases (I20-I25) Deaths                                       60069 non-null  float64
#  21  Malignant neoplasm of bronchus and lung (C34) Deaths                            46921 non-null  float64
#  22  Malignant neoplasms (C00-C97) Deaths                                            63463 non-null  float64
#  23  Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) Deaths    21359 non-null  float64
#  24  Other chronic obstructive pulmonary disease (J44) Deaths                        43287 non-null  float64
#  25  Parkinson disease (G20-G21) Deaths                                              11440 non-null  float64
#  26  Tuberculosis (A16-A19) Deaths                                                   104 non-null    float64
#  27  CO 1-hour 1971                                                                  4555 non-null   float64
#  28  CO 8-hour 1971                                                                  4555 non-null   float64
#  29  Lead 3-Month 2009                                                               991 non-null    float64
#  30  NO2 1-hour 2010                                                                 5525 non-null   float64
#  31  NO2 Annual 1971                                                                 5526 non-null   float64
#  32  Ozone 8-hour 2015                                                               16742 non-null  float64
#  33  PM10 24-hour 2006                                                               9201 non-null   float64
#  34  PM25 24-hour 2012                                                               13592 non-null  float64
#  35  PM25 Annual 2012                                                                13592 non-null  float64
#  36  SO2 1-hour 2010                                                                 7143 non-null   float64
#  37  SO2 3-hour 1971                                                                 7143 non-null   float64
#  38  Lead 3-Month 2009 1 and 2 Indicator                                             991 non-null    float64
#  39  PM25 Annual 2012 1 Indicator                                                    13592 non-null  float64
#  40  PM25 Annual 2012 2 Indicator                                                    13592 non-null  float64
#  41  PM25 24-hour 2012 1 and 2 Indicator                                             13592 non-null  float64
#  42  SO2 1-hour 2010 1 Indicator                                                     7143 non-null   float64
#  43  SO2 3-hour 1971 2 Indicator                                                     7143 non-null   float64
#  44  Physically Unhealthy Days                                                       29836 non-null  float64
#  45  Mentally Unhealthy Days                                                         29370 non-null  float64
#  46  % LBW                                                                           29746 non-null  float64
#  47  % Smokers                                                                       27925 non-null  float64
#  48  % Obese                                                                         31364 non-null  float64
#  49  % Physically Inactive                                                           31364 non-null  object
#  50  % Excessive Drinking                                                            27392 non-null  float64
#  51  PCP Rate                                                                        30261 non-null  float64
#  52  High School Grad Rate                                                           28671 non-null  float64
#  53  % Some College Education                                                        31363 non-null  float64
#  54  % Unemployed                                                                    31354 non-null  float64
#  55  % Uninsured                                                                     31354 non-null  float64
#  56  % Children in Poverty                                                           31354 non-null  float64
#  57  Income Ratio                                                                    31359 non-null  object
#  58  % Single-Parent Households                                                      31352 non-null  float64
#  59  Poverty Percent, All Ages                                                       31364 non-null  object
#  60  % Age < 18                                                                      28229 non-null  float64
#  61  % Age 65 and over                                                               28229 non-null  float64
#  62  % African American                                                              28229 non-null  float64
#  63  % Asian                                                                         28229 non-null  float64
#  64  % American Indian/Alaskan Native                                                28229 non-null  float64
#  65  % Native Hawaiian/Other Pacific Islander                                        28229 non-null  float64
#  66  % Hispanic                                                                      28229 non-null  float64
#  67  % Non-Hispanic White                                                            21959 non-null  float64
#  68  % Not Proficient in English                                                     28229 non-null  float64
#  69  % Female                                                                        28229 non-null  float64
#  70  % Rural                                                                         28213 non-null  float64
#  71  Median Household Income                                                         28220 non-null  float64
#  72  % high housing costs                                                            9405 non-null   float64
#  73  summer_tmmx                                                                     21749 non-null  float64
#  74  summer_rmax                                                                     21749 non-null  float64
#  75  winter_tmmx                                                                     21749 non-null  float64
#  76  winter_rmax                                                                     21749 non-null  float64
# dtypes: float64(70), int64(2), object(5)
# memory usage: 41.1+ MB

# %%
write_csv_file(AllData, 'AllData_7-12.csv')

# %% [markdown]
# ## Debug Space

# %%
merged_df.tail()
